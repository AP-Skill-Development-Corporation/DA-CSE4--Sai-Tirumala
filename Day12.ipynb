# %% [markdown]
# ### Today Topics
# - Continue with pandas
# - matplot library

# %% [markdown]
# #### working with .csv file
# - saving (excel) file with .csv(comma separated values) extension

# %%
import pandas as pd

# %%
std_data=pd.read_csv('students.csv')
std_data
# Out:
#     S.No. Registration Id                         Name  \
# 0       1      19AR1A0501          Aalla Lokesh Balaji
# 1       2      19AR1A0504  Raja Ravindra Kumar Anumula
# 2       3      19AR1A0505                 Navya Athoti
# 3       4      19AR1A0506                  Bandari Sai
# 4       5      19AR1A0507                    Venkatesh
# ..    ...             ...                          ...
# 69     70      19AR1A05C2                Kokila Vemula
# 70     71      19AR1A05C6            Y Anantha Ramaiah
# 71     72      19AR1A05C7              Yampati Triveni
# 72     73      19AR1A05C8                    Meghana.Y
# 73     74      19AR1A05C9         Yelchuri Surya Pavan
#
#                                  Email   Mobile No
# 0          aallalokeshbalaji@gmail.com  9182038940
# 1           rajaravindra2001@gmail.com  8008907930
# 2            navyaathoti2001@gmail.com  9059095687
# 3            saibandaru12345@gmail.com  7569765407
# ...

# %%
marks_df=pd.read_csv('marks.csv')
marks_df
# Out:
#     S.no   DS   ML  IOT  Elective  Other
# 0      1  100   90   90        92     96
# 1      2   88   80   81       100     97
# 2      3   85   87   92        84     94
# 3      4  100   94   80        93     81
# 4      5   95  100   95        84     90
# 5      6   98   87   80        89     94
# 6      7   83   86   91        95     91
# 7      8   96   96   98        94     98
# 8      9   82   91   84        98     97
# 9     10   93  100   84        82     98
# 10    11   83   89  100        80     99
# 11    12   94   90   93        85    100
# 12    13   91   93   87        93    100
# 13    14   92   82   98        89     83
# 14    15   92   89   96        93     91
# 15    16   91   80   99        81     82
# 16    17   82   89   84        86     89
# 17    18   91  100   88        90     83
# 18    19   97   95   85        90    100
# 19    20   87   98   85        98     98
# 20    21   95   85   80        89     98
# 21    22   90   86   89        97     96
# ...

# %%
pd.read_csv('students.csv',usecols=["Name",'Email'])
#you can read specific columns
# Out:
#                            Name                               Email
# 0           Aalla Lokesh Balaji         aallalokeshbalaji@gmail.com
# 1   Raja Ravindra Kumar Anumula          rajaravindra2001@gmail.com
# 2                  Navya Athoti           navyaathoti2001@gmail.com
# 3                   Bandari Sai           saibandaru12345@gmail.com
# 4                     Venkatesh  venkateshbandarupalli143@gmail.com
# ..                          ...                                 ...
# 69                Kokila Vemula                kokila4848@gmail.com
# 70            Y Anantha Ramaiah          ramuyamparala5c6@gmail.com
# 71              Yampati Triveni            yempatitriveni@gmail.com
# 72                    Meghana.Y           meghanayandluri@gmail.com
# 73         Yelchuri Surya Pavan             yelchurisurya@gmail.com
#
# [74 rows x 2 columns]

# %%
std_data.describe()
# Out:
#            S.No.     Mobile No
# count  74.000000  7.400000e+01
# mean   37.500000  8.879428e+09
# std    21.505813  8.018280e+08
# min     1.000000  7.013100e+09
# 25%    19.250000  8.405931e+09
# 50%    37.500000  9.132333e+09
# 75%    55.750000  9.392650e+09
# max    74.000000  9.985368e+09

# %%
std_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   S.No.            74 non-null     int64
#  1   Registration Id  74 non-null     object
#  2   Name             74 non-null     object
#  3   Email            74 non-null     object
#  4   Mobile No        74 non-null     int64
# dtypes: int64(2), object(3)
# memory usage: 3.0+ KB

# %%
std_data.iloc[13:34,1:].value_counts()
# Out:
# Registration Id  Name                            Email                              Mobile No
# 19AR1A0531       Garlapati Nikhil Sai            garlapatinikhilsai@gmail.com       8186047468    1
# 19AR1A0551       Jupalli Venkata Sai Kumar       saikumarjupalli1919@gmail.com      9346034769    1
# 19ar1a0543       Illuri Madhavi                  illurimadhavireddy@gmail.com       8978577181    1
# 19AR1A0566       Konikineni Bhargav              bhargavchowdary4790@gmail.com      9392987346    1
# 19AR1A0565       Konijeti Devi Sai Swetha        swethakonijeti5@gmail.com          9110555692    1
# 19AR1A0564       Vaishnavi Kondrakunta           vaishnavikondrakunta333@gmail.com  9963469524    1
# 19AR1A0558       Kilaru Rushitha                 rushithachowdary188@gmail.com      8500765431    1
# 19AR1A0557       Gnana Lakshmi Prasanna Kilaru   gnanakilaru@gmail.com              8309103700    1
# ...

# %%
std_data.isnull()
# Out:
#     S.No.  Registration Id   Name  Email  Mobile No
# 0   False            False  False  False      False
# 1   False            False  False  False      False
# 2   False            False  False  False      False
# 3   False            False  False  False      False
# 4   False            False  False  False      False
# ..    ...              ...    ...    ...        ...
# 69  False            False  False  False      False
# 70  False            False  False  False      False
# 71  False            False  False  False      False
# 72  False            False  False  False      False
# 73  False            False  False  False      False
#
# [74 rows x 5 columns]

# %%
marks_df>90
# Out:
#      S.no     DS     ML    IOT  Elective  Other
# 0   False   True  False  False      True   True
# 1   False  False  False  False      True   True
# 2   False  False  False   True     False   True
# 3   False   True   True  False      True  False
# 4   False   True   True   True     False  False
# 5   False   True  False  False     False   True
# 6   False  False  False   True      True   True
# 7   False   True   True   True      True   True
# 8   False  False   True  False      True   True
# 9   False   True   True  False     False   True
# 10  False  False  False   True     False   True
# 11  False   True  False   True     False   True
# 12  False   True   True  False      True   True
# 13  False   True  False   True     False  False
# 14  False   True  False   True      True   True
# 15  False   True  False   True     False  False
# 16  False  False  False  False     False  False
# 17  False   True   True  False     False  False
# 18  False   True   True  False     False   True
# ...

# %%
marks_df[marks_df>90] #fancy indexing
# Out:
#     S.no     DS     ML    IOT  Elective  Other
# 0    NaN  100.0    NaN    NaN      92.0   96.0
# 1    NaN    NaN    NaN    NaN     100.0   97.0
# 2    NaN    NaN    NaN   92.0       NaN   94.0
# 3    NaN  100.0   94.0    NaN      93.0    NaN
# 4    NaN   95.0  100.0   95.0       NaN    NaN
# 5    NaN   98.0    NaN    NaN       NaN   94.0
# 6    NaN    NaN    NaN   91.0      95.0   91.0
# 7    NaN   96.0   96.0   98.0      94.0   98.0
# 8    NaN    NaN   91.0    NaN      98.0   97.0
# 9    NaN   93.0  100.0    NaN       NaN   98.0
# 10   NaN    NaN    NaN  100.0       NaN   99.0
# 11   NaN   94.0    NaN   93.0       NaN  100.0
# 12   NaN   91.0   93.0    NaN      93.0  100.0
# 13   NaN   92.0    NaN   98.0       NaN    NaN
# 14   NaN   92.0    NaN   96.0      93.0   91.0
# 15   NaN   91.0    NaN   99.0       NaN    NaN
# 16   NaN    NaN    NaN    NaN       NaN    NaN
# 17   NaN   91.0  100.0    NaN       NaN    NaN
# 18   NaN   97.0   95.0    NaN       NaN  100.0
# ...

# %% [markdown]
# #### Matplot library
# - used for data visualization
# - matplot library,seaborn

# %%
import matplotlib.pyplot as plt

# %%
dir(plt)
# Out:
# ['Annotation',
#  'Arrow',
#  'Artist',
#  'AutoLocator',
#  'Axes',
#  'Button',
#  'Circle',
#  'Figure',
#  'FigureCanvasBase',
#  'FixedFormatter',
#  'FixedLocator',
#  'FormatStrFormatter',
#  'Formatter',
#  'FuncFormatter',
#  'GridSpec',
#  'IndexLocator',
#  'Line2D',
#  'LinearLocator',
#  'Locator',
#  'LogFormatter',
#  'LogFormatterExponent',
#  'LogFormatterMathtext',
#  'LogLocator',
#  'MaxNLocator',
#  'MouseButton',
#  'MultipleLocator',
#  'Normalize',
#  'NullFormatter',
#  'NullLocator',
#  'Number',
#  'PolarAxes',
#  'Polygon',
#  'Rectangle',
#  'ScalarFormatter',
#  'Slider',
#  'Subplot',
#  'SubplotSpec',
#  'Text',
#  'TickHelper',
#  'Widget',
#  '_INSTALL_FIG_OBSERVER',
#  '_IP_REGISTERED',
#  '_IoffContext',
#  '_IonContext',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_api',
#  '_auto_draw_if_interactive',
#  '_backend_mod',
#  '_copy_docstring_and_deprecators',
# ...

# %%
x=[4,5,6,8,7]
y=[.4,3.5,4.6,7.8,10.3]
plt.plot(x,y)
plt.title('Basic Graph')
plt.show()

# %%
x=[1,2,3,4,5]
y=[10,20,30,40,50]
z=[34.5,67.8,56.7,34.5,23.6]
plt.plot(x,y) # plotting sample line graph b/w x&y
plt.xlabel('x-axis') # adding label on the x-axis
plt.ylabel('y-axis')
plt.show()

# %%
plt.plot(x,z)
plt.show()

# %%
plt.plot(y,z)

# %%
#while plotting the multiple plot in a plain
plt.plot(x,y,label='first')
plt.plot(x,z,label="second")
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.legend(loc=2) # upper right by default unless you pass loc=value
plt.title("Second Graph")
plt.show()

# %%
plt.plot(x,y,linestyle='--',color='red')
plt.show()

# %%
import numpy as np

# %%
rn=np.random.randint(40,100,10)
sec=marks_df['IOT'].head(10)
print(rn)
print(sec)
# Out:
# [45 57 87 77 41 54 58 44 92 53]
# 0    90
# 1    81
# 2    92
# 3    80
# 4    95
# 5    80
# 6    91
# 7    98
# 8    84
# 9    84
# Name: IOT, dtype: int64

# %%
plt.plot(rn,sec,color='g',marker='*',linestyle='dashed')
plt.show()

# %%
plt.bar(rn,sec,color='m')
plt.show() # bar graph

# %%
plt.barh(sec,rn,color='y')
plt.show() #horizontal bars

# %%
classes=['Python','DA','R','AI','ML']
st1=[10,40,30,40,20]
st2=[50,30,27,15,60]
st3=[20,15,5,30,23]
plt.bar(classes,st1)
# Out:
# <BarContainer object of 5 artists>

# %%
from matplotlib import style
style.use('ggplot')
plt.bar(classes,st2)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.bar(classes,st2,color='black')
# Out:
# <BarContainer object of 5 artists>

# %%
#attributes to the bar graph
plt.bar(classes,st3,width=0.5,color='y',align='edge',edgecolor='m',linestyle='-.',linewidth=0.8)
# Out:
# <BarContainer object of 5 artists>

# %%
#multiple bar graphs in a plain
plt.bar(classes,st1)
plt.bar(classes,st2)
plt.bar(classes,st3)
# Out:
# <BarContainer object of 5 artists>

# %%
#scatter plot
#scattering the points
x=np.linspace(1,10,40)
y=np.sin(x)
plt.scatter(x,y,color='g',s=40) # s means size of the point/marker
plt.show()

# %%
#histogram
#plt.hist
one=np.random.randint(10,40,100)
two=np.random.randint(15,40,100)
plt.hist(one,color='b',bins=50)# for 100 data points,50 bins representation
plt.xlabel('Age category')
plt.ylabel('Voters')
plt.show()

# %%
plt.hist(two,bins=20,color='g',orientation='horizontal')
plt.show()

# %%
plt.hist(one,color='y',bins=40)
plt.hist(two,color='g',bins=60)
plt.title('Multi Histograms')
plt.show()

# %%
# pie plot
#making the regions
x=[56,25,30,24]
plt.pie(x)
plt.show()

# %%
plt.pie(rn)
plt.show()

# %%
plt.pie(sec)
plt.show()

# %%
plt.pie(x,labels=['Good','Average','Above average','Excellent'])
plt.show()

# %%
fbk=['Good','Average','Above average','Excellent']
plt.pie(x,colors=['green','cyan','blue','pink'],labels=fbk)
plt.show()

# %%
fbk=['Good','Average','Above average','Excellent']
plt.pie(x,colors=['green','cyan','blue','pink'],labels=fbk,autopct='%f.%%')
plt.title('Sort by Responses')
plt.show()

# %%
#exclude some part from the plot
exc=[0,0,0,1]
plt.pie(x,labels=fbk,colors=['green','cyan','blue','pink'],autopct='%f.%%',
        shadow=True,startangle=180,explode=exc)
plt.title('Excluded')
plt.show()

# %%
#one by one arragement
#scatter plot
a=[9,3,5,4,8]
b=[9,4,5,6,2]
c=[6,8,2,3,1]
x=np.array([8,4,9,4,2])
plt.stackplot(x,a,b,c)
plt.show()

# %%
f=[1,2,3,4,5]
s={'y1':[5,6,4,5,7],'y2':[1,6,4,5,6],
  'y3':[1,1,2,3,4]}
plt.stackplot(f,s.values())
plt.show()

# %%
plt.stackplot(f,s.values(),labels=s.keys())
plt.legend(loc='upper left')
plt.show()
